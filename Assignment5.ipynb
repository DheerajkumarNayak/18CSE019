# %% [markdown]
# <a href="https://colab.research.google.com/github/DheerajkumarNayak/18CSE019/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/chirudukuru/DMDW/main/student-mat.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib','inline')
plt.style.use('seaborn-whitegrid')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0       GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1       GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2       GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3       GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4       GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# ..     ...  ..  ...     ...     ...     ...  ...   ...     ...      ...  ..  ..  ..
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# ...

# %%
df1=df[['traveltime','studytime']]

# %%
df1.head()
# Out:
#    traveltime  studytime
# 0           2          2
# 1           1          2
# 2           1          2
# 3           1          3
# 4           1          2

# %%
x=df1['traveltime']
y=df1['studytime']

# %%
sns.lineplot(x,y,dashes=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from scipy.stats import norm

# %%
correlation=df1.corr()
print(correlation)
# Out:
#             traveltime  studytime
# traveltime    1.000000  -0.100909
# studytime    -0.100909   1.000000

# %%
sns.heatmap(correlation,cmap='BrBG')
plt.show()

# %%
covar=df1.cov()
print(covar)
# Out:
#             traveltime  studytime
# traveltime    0.486513  -0.059070
# studytime    -0.059070   0.704324

# %%
sns.heatmap(covar)
plt.show()

# %%
#Normalization

# %%
df
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0       GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1       GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2       GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3       GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4       GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# ..     ...  ..  ...     ...     ...     ...  ...   ...     ...      ...  ..  ..  ..
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# ...

# %%
age=np.array(df['age'])
age
# Out:
# array([18, 17, 15, 15, 16, 16, 16, 17, 15, 15, 15, 15, 15, 15, 15, 16, 16,
#        16, 17, 16, 15, 15, 16, 16, 15, 16, 15, 15, 16, 16, 15, 15, 15, 15,
#        16, 15, 15, 16, 15, 15, 16, 15, 15, 15, 16, 15, 16, 16, 15, 15, 16,
#        15, 15, 15, 15, 16, 15, 15, 15, 16, 16, 16, 16, 16, 15, 16, 15, 16,
#        15, 15, 16, 15, 15, 16, 16, 15, 15, 16, 17, 16, 15, 15, 15, 15, 15,
#        15, 16, 15, 16, 16, 16, 15, 16, 16, 15, 15, 16, 16, 16, 16, 16, 16,
#        15, 15, 15, 15, 15, 16, 15, 16, 15, 16, 16, 15, 15, 16, 15, 16, 17,
#        15, 15, 15, 16, 16, 16, 15, 15, 19, 18, 16, 15, 15, 17, 16, 15, 15,
#        17, 16, 16, 15, 15, 16, 15, 16, 17, 15, 15, 15, 16, 15, 18, 16, 15,
#        19, 17, 15, 17, 18, 16, 16, 17, 15, 16, 17, 17, 16, 16, 16, 16, 16,
#        16, 16, 17, 16, 16, 17, 16, 17, 16, 17, 16, 16, 17, 17, 16, 17, 16,
#        16, 17, 17, 16, 17, 17, 16, 16, 17, 17, 16, 17, 16, 16, 16, 17, 17,
# ...

# %%
print(max(age))
# Out:
# 22

# %%
print(min(age))
# Out:
# 15

# %%
from scipy import stats
zscore=np.array(stats.zscore (age))
zscore=zscore[0:394]

# %%
zscore
# Out:
# array([ 1.02304645,  0.23837976, -1.33095364, -1.33095364, -0.54628694,
#        -0.54628694, -0.54628694,  0.23837976, -1.33095364, -1.33095364,
#        -1.33095364, -1.33095364, -1.33095364, -1.33095364, -1.33095364,
#        -0.54628694, -0.54628694, -0.54628694,  0.23837976, -0.54628694,
#        -1.33095364, -1.33095364, -0.54628694, -0.54628694, -1.33095364,
#        -0.54628694, -1.33095364, -1.33095364, -0.54628694, -0.54628694,
#        -1.33095364, -1.33095364, -1.33095364, -1.33095364, -0.54628694,
#        -1.33095364, -1.33095364, -0.54628694, -1.33095364, -1.33095364,
#        -0.54628694, -1.33095364, -1.33095364, -1.33095364, -0.54628694,
#        -1.33095364, -0.54628694, -0.54628694, -1.33095364, -1.33095364,
#        -0.54628694, -1.33095364, -1.33095364, -1.33095364, -1.33095364,
#        -0.54628694, -1.33095364, -1.33095364, -1.33095364, -0.54628694,
#        -0.54628694, -0.54628694, -0.54628694, -0.54628694, -1.33095364,
# ...

# %%
#decimal normalization

# %%
dn=[]
dn.append(age/pow(10,2))
dn=np.array(dn)
print(dn)
# Out:
# [[0.18 0.17 0.15 0.15 0.16 0.16 0.16 0.17 0.15 0.15 0.15 0.15 0.15 0.15
#   0.15 0.16 0.16 0.16 0.17 0.16 0.15 0.15 0.16 0.16 0.15 0.16 0.15 0.15
#   0.16 0.16 0.15 0.15 0.15 0.15 0.16 0.15 0.15 0.16 0.15 0.15 0.16 0.15
#   0.15 0.15 0.16 0.15 0.16 0.16 0.15 0.15 0.16 0.15 0.15 0.15 0.15 0.16
#   0.15 0.15 0.15 0.16 0.16 0.16 0.16 0.16 0.15 0.16 0.15 0.16 0.15 0.15
#   0.16 0.15 0.15 0.16 0.16 0.15 0.15 0.16 0.17 0.16 0.15 0.15 0.15 0.15
#   0.15 0.15 0.16 0.15 0.16 0.16 0.16 0.15 0.16 0.16 0.15 0.15 0.16 0.16
#   0.16 0.16 0.16 0.16 0.15 0.15 0.15 0.15 0.15 0.16 0.15 0.16 0.15 0.16
#   0.16 0.15 0.15 0.16 0.15 0.16 0.17 0.15 0.15 0.15 0.16 0.16 0.16 0.15
#   0.15 0.19 0.18 0.16 0.15 0.15 0.17 0.16 0.15 0.15 0.17 0.16 0.16 0.15
#   0.15 0.16 0.15 0.16 0.17 0.15 0.15 0.15 0.16 0.15 0.18 0.16 0.15 0.19
#   0.17 0.15 0.17 0.18 0.16 0.16 0.17 0.15 0.16 0.17 0.17 0.16 0.16 0.16
#   0.16 0.16 0.16 0.16 0.17 0.16 0.16 0.17 0.16 0.17 0.16 0.17 0.16 0.16
# ...
